# %%
import xarray as xr

ds = xr.open_dataset("../data/mask_weddell_subset.nc")
ds = ds["tmask"].squeeze(["t", "z"]).transpose("x", "y")
ds.to_netcdf("../data/weddell_mask.nc")

# %%
import xarray as xr

ds = xr.open_dataset("../data/2d/evp_1200itr_ts_dr710o_1ts_19760101_19760101_icemod_subset.nc")
ds.data_vars
# Out:
# Data variables:
#     area                  (y, x) float32 142kB ...
#     bounds_nav_lat        (y, x, nvertex) float32 568kB ...
#     bounds_nav_lon        (y, x, nvertex) float32 568kB ...
#     normstr               (time_counter, y, x) float32 7MB ...
#     sheastr               (time_counter, y, x) float32 7MB ...
#     siconc                (time_counter, y, x) float32 7MB ...
#     sidive                (time_counter, y, x) float32 7MB ...
#     sishea                (time_counter, y, x) float32 7MB ...
#     sistre                (time_counter, y, x) float32 7MB ...
#     sithic                (time_counter, y, x) float32 7MB ...
#     sivelo                (time_counter, y, x) float32 7MB ...
#     sivelu                (time_counter, y, x) float32 7MB ...
#     sivelv                (time_counter, y, x) float32 7MB ...
#     sivolu                (time_counter, y, x) float32 7MB ...
#     sivpnd                (time_counter, y, x) float32 7MB ...
# ...
